# %% [markdown]
# # 02 Model Training
#
# Run the reproducible training pipeline and persist production artifacts.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd

from src.train import train_model
from src.utils import DEFAULT_DATA_PATH, REPORTS_DIR, artifact_paths, load_config, load_json

# %%
result = train_model(DEFAULT_DATA_PATH)
result

# %%
comparison = pd.read_csv(REPORTS_DIR / 'model_comparison.csv')
comparison.sort_values('roc_auc', ascending=False)

# %%
importance = pd.read_csv(REPORTS_DIR / 'feature_importance.csv')
importance.head(20)

# %%
paths = artifact_paths(load_config())
{name: str(path) for name, path in paths.items()}

# %%
metrics = load_json(paths['metrics_path'])
metrics['selected_model'], metrics['test_metrics']
